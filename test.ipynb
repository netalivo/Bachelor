# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Residuen Mittelwerte

# %%
sarima_resid_bias = [0.04257806195218261, 0.04212550917521533, 0.035532620472646555, -0.06545951514208018, 0.07503876378493929, -0.011021015060687984, 0.9659694025524008, 0.038321221765876455, 0.039168060055965515, 0.05166890826701782, 0.040235670510164606, 0.05371608634500941, 0.08041740049103183, -0.02309484549376228, 0.0736839133896954, 0.10641540847323275, 0.09702080111366204, 0.05368462123657899, 0.05835464131982214, 0.041048597142131237, 0.0676246702953675, 0.07865613727607425, 0.08642538273638353, 0.05812098301177866, 0.09122993759888963, 0.053799243355098385, 0.04574637322452767, -0.03641073149593433, 0.05006595201060273, -0.06283696216320264, 0.15518081981391596, 0.09051880795529373, -0.052510530845599354, 0.1036055456806939, 0.02020468720501444, -0.10252970568121351, -0.1041007530752315, -0.07879054839012464, 0.05022865760123802, 0.08911744168093345, 0.07123005108422938, -0.08011776994941519, -0.10235677197253053, -0.0021507807598363867, 0.0661443432046069]
naiv_resid_bias = [0.008154904964496442, 0.005194927305058506, 0.0064004588466191024, 0.00871673911635864, 0.013835870044605555, 0.00683958019450436, 0.011441017238919212, 0.00789691341812474, 0.014347969263546147, 0.00803811700363059, 0.011137289951741559, 0.014854209154550614, 0.011319375036614966, 0.008153213703888908, 0.0048794057331752036, 0.012844295956666318, 0.011573488842746137, 0.006676152583262509, 0.006472671812765129, 0.008392013668456693, 0.009858297243282828, 0.012605014713158176, 0.0019436819436496485, 0.008405374507131455, 0.006289165730476905, 0.008275777667685226, 0.007426109527647773, 0.008672119349068834, 0.008240537139433915, -0.008507866719492468, 0.011464140277216518, 0.01084030886691117, -0.002114951498093073, 0.0059126309140266, 0.0161536560252323, -0.030091730477923986, -0.0033909157399523633, 0.01477248687771083, 0.01573715519373129, 0.007805665007442603, 0.01454349063851084, 0.005442465078916672, -0.007754068363713059, 0.010373378956563331, 0.013026851083940933]

fig, ax = plt.subplots()
ax.boxplot([naiv_resid_bias, sarima_resid_bias], patch_artist=True, showmeans=True, widths=[0.3, 0.3])
ax.set_xticklabels(['Saisonal Naiv', 'SARIMA'])
ax.set_ylabel('Residuen')
ax.set_title('Standardisierte Residuen-Mittelwerte aller Zeitreihen')
ax.set_ylim(-0.2, 0.2)  
plt.axhline(0, ls='--', lw=0.8)
plt.tight_layout()
plt.show()

print('NAIV Mittelwert:', pd.Series(naiv_resid_bias).mean(), 'Median:', pd.Series(naiv_resid_bias).median())
print('SARIMA Mittelwert:', pd.Series(sarima_resid_bias).mean(), 'Median:', pd.Series(sarima_resid_bias).median())
# Out:
# NAIV Mittelwert: 0.007402164172939871 Median: 0.008275777667685226
# SARIMA Mittelwert: 0.052255528705613376 Median: 0.05022865760123802

# %% [markdown]
# SMAPE

# %%
naiv_smape = [5.9530026965794205, 5.902598000158378, 6.634969384029605, 5.653606797355883, 6.835319801056889, 6.290592231012177, 7.293410797888406, 6.027232348716425, 5.971220969291638, 5.529742918031621, 6.075476099346715, 6.324373528850595, 6.00889744942883, 9.098313019616052, 8.139124673088036, 6.703957945045948, 7.698820513030115, 9.00344638216611, 6.75343684838903, 7.232735359792149, 6.946826563677347, 7.65531919899279, 8.84546397983731, 7.486637060972049, 6.514385940175002, 7.020733043698399, 8.76148097527435, 9.949240511795617, 8.6903508114113, 3.7310702821114927, 5.110637275121996, 5.195027548440403, 6.721298060777749, 5.420999664687818, 10.41650270626857, 4.882433288926234, 3.721643296745104, 5.436395783943512, 6.215134977504002, 7.439729590247428, 6.4589893607240505, 6.5767034589613775, 4.768101082130463, 4.717821255795954, 7.992584235585911]
sarima_smape = [5.340887827106428, 5.570973762357464, 5.869182709223505, 5.98434057755706, 5.734765584255979, 6.51788165028907, 43.83446654363462, 5.6147916717089865, 6.96686878678198, 5.873127820231772, 6.108987633881199, 5.946098438371357, 5.7262876392741955, 7.27614964684393, 7.431086526688503, 6.642597505398952, 8.122223817727491, 8.150277464508129, 6.441625469730032, 6.746203979040044, 7.1135625057326815, 6.988348700719149, 8.414609399437435, 6.744242605476547, 6.312627650022204, 6.196873855896265, 7.411740951669486, 8.474542238658806, 7.857015636648608, 3.6171439180847162, 5.970499824426546, 4.991063039846791, 7.351404754983049, 5.786081297643708, 10.320371498703661, 4.9511036527635985, 4.276523106759148, 5.874528246134306, 7.206068675506788, 6.715294261905928, 7.41774798249631, 7.034324144310489, 5.197024931663817, 4.673807317764492, 6.894557463759875]

fig, ax = plt.subplots()
ax.boxplot([naiv_smape, sarima_smape], patch_artist=True, showmeans=True, widths=[0.3, 0.3])
ax.set_xticklabels(['Saisonal Naiv', 'SARIMA'])
ax.set_ylabel('sMAPE (%)')
ax.set_title('sMAPE aller Zeitreihen (in-sample)')
ax.set_ylim(0, 15)  
plt.tight_layout()
plt.show()

print('NAIV Mittelwert:', pd.Series(naiv_smape).mean(), 'Median:', pd.Series(naiv_smape).median())
print('SARIMA Mittelwert:', pd.Series(sarima_smape).mean(), 'Median:', pd.Series(sarima_smape).median())
# Out:
# NAIV Mittelwert: 6.706795282592895 Median: 6.5767034589613775
# SARIMA Mittelwert: 7.326442949236112 Median: 6.51788165028907

# %% [markdown]
# Durbin Watson

# %%
naiv_dw = [2.7146724074428352, 2.7247710301042174, 2.584930696637733, 2.7451454825392623, 2.799699075351027, 2.6215101791387987, 2.613693982582782, 2.713121400032987, 2.7225498261471484, 2.581300006195319, 2.552540386354194, 2.7138638963134607, 2.7370250050930602, 2.7677326855103495, 2.6485131718949684, 2.6776694577180664, 3.180873543872119, 2.8333389881452677, 2.7107960039892096, 2.7391683942246456, 2.5378372780372747, 2.7231138506635464, 2.577938096001692, 2.7205456860697628, 2.5587303356641904, 2.877016351872089, 2.7978766547798726, 2.9215592568771926, 2.6341782462843186, 2.961127600434091, 2.7308717348098765, 2.777339172324431, 2.333455675700808, 2.7671840821931064, 2.696113299456546, 2.6197325274422227, 3.076104339836067, 2.9837495690770344, 2.784333590343012, 2.8717564742787327, 2.90804414624634, 2.3017403598611232, 2.612068030931472, 3.160927760762069, 2.7027239445084272]
sarima_dw = [2.0322854936903503, 1.8318644589001882, 1.9132753384795216, 2.2631525664596346, 2.024370020309847, 1.9702076654788983, 0.7243254463694946, 1.8060785589188815, 2.0953307730674635, 1.8731698364165632, 1.8013883626645342, 1.8613676045577185, 1.8356430909408732, 1.919124922729754, 1.8788956471986495, 1.920454729475074, 1.9453461606468239, 1.8645767548075087, 1.7998977229978212, 1.77684385897018, 1.886507112481631, 1.8630971683156619, 1.8602438030781583, 1.9316038156904414, 1.8596688212263097, 1.8143864261504061, 1.8405171965983604, 1.836472342193432, 2.07716139544867, 2.628363925375534, 2.0668676154952244, 1.8199264859002373, 2.361104494028315, 2.7706712908847737, 2.002322557497815, 2.361341331785819, 2.1345637384884553, 2.4539936779315035, 1.9853138821802752, 2.0954458373966998, 2.0024595925042505, 2.0189223518001547, 2.029356973496512, 2.6558427963572586, 1.8184775744894817]


fig, ax = plt.subplots()
ax.boxplot([naiv_dw, sarima_dw], patch_artist=True, showmeans=True, widths=[0.3, 0.3])
ax.set_xticklabels(['Saisonal Naiv', 'SARIMA'])
ax.set_ylabel('Durbin-Watson Statistik')
ax.set_title('Durbin-Watson-Statistik aller Zeitreihen')
ax.set_ylim(0, 4)  
plt.axhline(1.68, color='blue', linestyle='--', label='dU')
plt.axhline(4-1.68, color='blue', linestyle='--', label='4-dU')
plt.axhline(1.63, color='red', linestyle='--', label='dL')
plt.axhline(4-1.63, color='red', linestyle='--', label='4-dL')
plt.tight_layout()
plt.show()

# %% [markdown]
# ACF Plot Spikes

# %%
naiv_spikes = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 2, 3, 3, 4, 3, 3, 15, 3, 3, 9, 2, 7, 4, 4, 4, 14, 9, 6, 3]
sarima_spikes = [2, 2, 1, 3, 2, 0, 20, 2, 0, 1, 1, 1, 1, 1, 1, 0, 1, 1, 1, 1, 2, 1, 1, 0, 1, 2, 1, 1, 2, 3, 1, 2, 15, 3, 1, 12, 1, 1, 1, 1, 1, 4, 0, 1, 1]

fig, ax = plt.subplots()
ax.boxplot([naiv_spikes, sarima_spikes], patch_artist=True, showmeans=True, widths=[0.3, 0.3])
ax.set_xticklabels(['Saisonal Naiv', 'SARIMA'])
ax.set_ylabel('Anzahl der Spikes außerhalb ±1.96/√T')
ax.set_title('Verteilung der Anzahl signifikanter ACF-Spikes')
ax.set_ylim(-1, 20)  
plt.tight_layout()
plt.axhline(1, color='red', linestyle='--')
plt.show()
