# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Residuen Mittelwerte

# %%
sarima_resid_bias = [-0.1494412708324942, 0.09330641388708093, -0.12171541005813759, -0.17812921752790647, -0.10993779320839625, 0.16595322879325117, -0.1151761932262965, 0.1686452929077035, -0.1499185329808553, 0.13983308132684388, 0.138579581839848, 0.19298541312878476, 0.17701170312292605, -0.28053869960720373, 0.17614002321556288, 0.1372928156697791, -0.11098136024245206, 0.1281248579339643, 0.11314488538212059, 0.10030763893048905, -0.172671563286633, 0.1525978029112963, 0.09280555138149249, 0.10851038656738177, 0.13398706792877108, 0.12544365881875022, 0.08533469972024481, 0.03793342319043336, 0.1572994459696963, -0.054946177869815246, 0.13593151034052894, 0.14995370271210223, 0.011279103005747833, 0.08216550822853562, -0.022497160203419905, -0.11003298412406677, -0.048155336071994605, -0.10018383831036046, -0.07877476204894211, 0.12085357199367772, -0.13497687315936568, -0.10023841785777342, -0.055243428240579796, -0.0014641267798153168, 0.15580875818621026]
naiv_resid_bias = [0.9137485828097497, -0.05654306140055216, 0.9109773495875163, 1.553721703421664, 0.9914498171679798, 0.11216500315427229, 1.1055389427393962, 0.6618646312750566, 1.2466427341079762, -0.1941677197086645, 0.3818032007141669, 0.5618912025796143, 0.7265873627779487, -0.7833907835865289, -0.5406388963131722, 0.3961555338260691, 1.1739341163281036, -0.22221315871060554, -0.40938620465985137, 0.29626440784505487, -0.31149808820734914, -0.01111806324849612, 0.21735918350688996, -0.04987469495785347, 0.024134881410356687, 0.29785662816780123, -0.5255954079496807, -0.0754278194856686, -0.09194488846217004, -0.30655663761621577, 0.6032322645347523, 0.8739941266503743, -0.03126976484676688, 0.614067350249969, -0.650977414993025, -3.1284135698805686, 0.5470240093034193, 2.010377436390298, 1.584295425112044, 0.37649558246750564, 1.817539001825449, 1.1625938513738148, -0.3416821537214589, 1.6512825298852234, 0.09570823185470828]

fig, ax = plt.subplots()
ax.boxplot([naiv_resid_bias, sarima_resid_bias], patch_artist=True, showmeans=True, widths=[0.3, 0.3])
ax.set_xticklabels(['Saisonal Naiv', 'SARIMA'])
ax.set_ylabel('Residuen')
ax.set_title('Standardisierte Residuen-Mittelwerte aller Zeitreihen')
ax.set_ylim(-2.1, 2.1)  
plt.axhline(0, ls='--', lw=0.8)
plt.tight_layout()
plt.show()

print('NAIV Mittelwert:', pd.Series(naiv_resid_bias).mean(), 'Median:', pd.Series(naiv_resid_bias).median())
print('SARIMA Mittelwert:', pd.Series(sarima_resid_bias).mean(), 'Median:', pd.Series(sarima_resid_bias).median())
# Out:
# NAIV Mittelwert: 0.33728903918485653 Median: 0.29785662816780123
# SARIMA Mittelwert: 0.026360132921260326 Median: 0.08533469972024481

# %% [markdown]
# SMAPE

# %%
sarima_dw = [2.0617706458609018, 2.2549570914979613, 2.1505788665041607, 2.028892058310495, 1.8047918170397264, 1.9243938941047645, 1.3459682984930939, 1.63035020494066, 1.8598802936357313, 2.216265862974998, 1.7389278155374805, 1.5714660531544469, 1.8815690075297613, 1.7611548609928498, 2.0174648569338673, 2.0332234218072536, 1.5227921854848552, 2.38539483097851, 1.9110704934906566, 1.8317591065645376, 1.9098043812198287, 2.1906576795308816, 2.5316038047702394, 2.0147978794539614, 2.162920936760812, 2.1504554635686923, 2.084048389685444, 2.182949654567403, 2.08072016836637, 2.6847137790060414, 2.1930639834807706, 1.9181952549798182, 2.964784667401916, 2.1388415770099543, 1.8099122274134354, 2.3287956947312303, 2.7553724215890076, 1.4275531391833818, 1.7960469232412128, 2.0478127886866573, 1.6363245477204165, 1.2186294503210886, 2.562827310313722, 2.581676900891106, 1.8590874490579898]


fig, ax = plt.subplots()
ax.boxplot([naiv_dw, sarima_dw], patch_artist=True, showmeans=True, widths=[0.3, 0.3])
ax.set_xticklabels(['Saisonal Naiv', 'SARIMA'])
ax.set_ylabel('Durbin-Watson Statistik')
ax.set_title('Durbin-Watson-Statistik aller Zeitreihen')
ax.set_ylim(0, 4)  
plt.axhline(1.68, color='blue', linestyle='--', label='dU')
plt.axhline(4-1.68, color='blue', linestyle='--', label='4-dU')
plt.axhline(1.63, color='red', linestyle='--', label='dL')
plt.axhline(4-1.63, color='red', linestyle='--', label='4-dL')
plt.tight_layout()
plt.show()

# %% [markdown]
# ACF Plot Spikes

# %%
naiv_spikes = [0, 18, 7, 2, 6, 13, 7, 2, 1, 2, 1, 3, 2, 9, 0, 3, 4, 16, 1, 0, 2, 0, 4, 2, 11, 5, 0, 2, 1, 18, 15, 2, 18, 0, 18, 5, 1, 10, 6, 2, 1, 7, 11, 16, 0]
sarima_spikes = [1, 0, 0, 1, 1, 0, 0, 0, 0, 1, 1, 0, 0, 1, 0, 0, 0, 1, 1, 3, 0, 1, 6, 2, 1, 1, 0, 5, 1, 1, 0, 2, 5, 0, 1, 8, 2, 0, 0, 3, 0, 0, 2, 1, 0]

fig, ax = plt.subplots()
ax.boxplot([naiv_spikes, sarima_spikes], patch_artist=True, showmeans=True, widths=[0.3, 0.3])
ax.set_xticklabels(['Saisonal Naiv', 'SARIMA'])
ax.set_ylabel('Anzahl der Spikes außerhalb ±1.96/√T')
ax.set_title('Verteilung der Anzahl signifikanter ACF-Spikes')
ax.set_ylim(-1, 20)  
plt.tight_layout()
plt.axhline(1, color='red', linestyle='--')
plt.show()
